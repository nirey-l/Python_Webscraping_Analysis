# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-libmamba-solver, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, PyGithub, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.13.5
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve, typing-extensions
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.5
# bs4 버전 = 4.13.5

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
# url = 'https://news.naver.com/section/105'

# dict 타입으로 요청 파라미터 설정
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보 (사람처럼 보이게 하기 위함)
# 개발자 도구 네트워크 Doc의 헤더
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)

# print(res.text)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성 
print(res.status_code)
print(res.ok)
print(type(res))

#  CSS 선택자
# print(soup.select("div.sa_text a[href*='mnews/article']"))
# *= : 부분 매칭, ^= : 시작 부분 매칭
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")))
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
    print(type(a_tags), type(a_tags[0])) # [Tag, Tag]
    for a_tag in a_tags:
        title = a_tag.text.strip() # 여백을 줄일 때는 strip() 시용
        link = a_tag['href'] # 해당하는 링크 가져오기
        print(title, link)
else:
        # 응답(response)이 Error이면 status code 출력
        print(f'Error Code = {res.status_code}')


# <a> 태그 리스트 순회하기    

# 응답(response)이 Error 이면 status code 출력
# Out:
# https://news.naver.com/section/105
# 200
# True
# <class 'requests.models.Response'>
# 88
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 데브시스터즈, 올해 키워드 ‘확장·진화’ 제시… 쿠키런 IP 성장 전략 공개 https://n.news.naver.com/mnews/article/366/0001140958
#  https://n.news.naver.com/mnews/article/comment/366/0001140958
# “술취해 여학우 성희롱, 일어날수 있는 일” 천하람 과거 지식인 답변 논란 https://n.news.naver.com/mnews/article/020/0003695252
#  https://n.news.naver.com/mnews/article/comment/020/0003695252
# 광고가 받치고 커머스가 끌었다…네이버, 작년 영업익 2조2081억원 https://n.news.naver.com/mnews/article/119/0003056719
#  https://n.news.naver.com/mnews/article/comment/119/0003056719
#  https://n.news.naver.com/mnews/article/comment/417/0001128541
# [시대Lab] "인간은 구경만 하라"…AI들만의 세상 '몰트북'이 던진 공포 https://n.news.naver.com/mnews/article/417/0001128540
#  https://n.news.naver.com/mnews/article/comment/417/0001128540
# 中 연구팀, 고난도 ‘양자암호통신’ 한계 넘었다… 100㎞ 거리서 성공 https://n.news.naver.com/mnews/article/020/0003695520
#  https://n.news.naver.com/mnews/article/comment/020/0003695520
# 유명인 네이버 '지식인' 답변 강제 노출 '대참사'..천하람 과거글 충격 https://n.news.naver.com/mnews/article/014/0005474342
#  https://n.news.naver.com/mnews/article/comment/014/0005474342
# "딥테크 성장 열쇠는 '인내자본'…기술금융체계 재설계 필요" https://n.news.naver.com/mnews/article/008/0005314875
#  https://n.news.naver.com/mnews/article/comment/008/0005314875
# “배달로 번 돈, 배달에 다 나가네”…8.2% 수수료에 불만 커진 입점업체들 https://n.news.naver.com/mnews/article/011/0004587327
#  https://n.news.naver.com/mnews/article/comment/011/0004587327
# AI 주도권 굳히는 알파벳…올해 자본지출 두 배로 늘린다 https://n.news.naver.com/mnews/article/293/0000079033
#  https://n.news.naver.com/mnews/article/comment/293/0000079033

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101, '사회':102, '생활/문화':103 ,'세계':104, 'IT/과학':105}

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name, '정치')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 / {url}')

    # 요청 헤더 설정
    req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
    }

    #응답 요청
    res = requests.get(url, headers=req_header)
    
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        # CSS 선택자를 사용해서 a tag 목록 가져오기
        a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
        print(type(a_tags), type(a_tags[0])) # [Tag, Tag]
        for a_tag in a_tags:
            title = a_tag.text.strip() # 여백을 줄일 때는 strip() 시용
            link = a_tag['href'] # 해당하는 링크 가져오기
            print(title, link)
    else:
        # 응답(response)이 Error이면 status code 출력
        print(f'Error Code = {res.status_code}')

# %%
print_news('세계')
# Out:
# 세계 뉴스 / https://news.naver.com/section/104
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 트럼프 "日총선, 일본 미래에 매우 중요…다카이치 지지" https://n.news.naver.com/mnews/article/079/0004113048
#  https://n.news.naver.com/mnews/article/comment/079/0004113048
# 엡스타인 연루 인사 파문…英스타머 총리직 ‘흔들’ https://n.news.naver.com/mnews/article/277/0005717774
#  https://n.news.naver.com/mnews/article/comment/277/0005717774
# [속보] ECB 5연속 금리 동결…예금금리 연 2.00％ 유지 https://n.news.naver.com/mnews/article/009/0005633257
#  https://n.news.naver.com/mnews/article/comment/009/0005633257
# 미·러·우 3자 종전협상에서 포로 314명 교환 합의 https://n.news.naver.com/mnews/article/056/0012119922
#  https://n.news.naver.com/mnews/article/comment/056/0012119922
# 콜드플레이 공연 불륜 생중계 女, '입장료 130만원' 위기관리 강사로 https://n.news.naver.com/mnews/article/003/0013753276
#  https://n.news.naver.com/mnews/article/comment/081/0003615157
# 팀 쿡 애플 CEO "5년, 10년뒤에 누가 이 자리 앉을지 고민" https://n.news.naver.com/mnews/article/001/0015889044
#  https://n.news.naver.com/mnews/article/comment/001/0015889044
# 멕시코, 트럼프 협박에도 쿠바 지원 모색…“석유 공급 협상 중” https://n.news.naver.com/mnews/article/028/0002790275
#  https://n.news.naver.com/mnews/article/comment/028/0002790275
# ICE 얼마나 비호감이면… 백악관 대변인, 답변 중 ‘버럭’ https://n.news.naver.com/mnews/article/022/0004103752
#  https://n.news.naver.com/mnews/article/comment/022/0004103752
# 포로 교환 성과 냈지만...미·러·우 3자 회담 제자리 걸음 https://n.news.naver.com/mnews/article/016/0002596845
#  https://n.news.naver.com/mnews/article/comment/016/0002596845
# '심리적 저항선' 깨졌다...지하실 향하는 비트코인, 두려운 시나리오 등장 [지금이뉴스] https://n.news.naver.com/mnews/article/052/0002311158
#  https://n.news.naver.com/mnews/article/comment/052/0002311158
# 뉴욕증시, 빅테크로 번진 소프트웨어 학살 공포…하락 마감 https://n.news.naver.com/mnews/article/055/0001330852
#  https://n.news.naver.com/mnews/article/comment/055/0001330852

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

# 이미지 경로를 주기 why? 이미지만 다운로드 받는 건 의미가 없기 때문
req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
